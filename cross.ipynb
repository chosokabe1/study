# %%
project = 'C:\ex\sen\data\max_square_high'

# %%
import glob
import os
# d1 = {}
# indistinguishable_path = "C:\ex\sen\data\max_square\indistinguishable"
# nothing_path = "C:\ex\sen\data\max_square\\nothing"
# for file in glob.glob(indistinguishable_path+"/*"):
#   sen_id = os.path.basename(file)[:3]
#   if sen_id in d1:
#     d1[sen_id] += 1
#   else:
#     d1[sen_id] = 1

# for file in glob.glob(nothing_path+'/*'):
#   sen_id = os.path.basename(file)[:3]
#   if sen_id in d1:
#     d1[sen_id] += 1
#   else:
#     d1[sen_id] = 1
# print(d1)

# %%
import csv
# with open('C:\ex\sen\data\max_square\cross\\nothing_indis_id_number.csv', 'w', newline="") as f:
#   writer = csv.writer(f)
#   for key, i in d1.items():
#     writer.writerow([str(key)+'\'', i])

# %%
with open('C:\ex\sen\data\max_square\cross\cross_egg_a.txt', 'r', encoding='UTF-8') as f:
  cross_egg_a_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_egg_b.txt', 'r', encoding='UTF-8') as f:
  cross_egg_b_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_egg_c.txt', 'r', encoding='UTF-8') as f:
  cross_egg_c_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_egg_d.txt', 'r', encoding='UTF-8') as f:
  cross_egg_d_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_egg_e.txt', 'r', encoding='UTF-8') as f:
  cross_egg_e_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_indis_a.txt', 'r', encoding='UTF-8') as f:
  cross_indis_a_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_indis_b.txt', 'r', encoding='UTF-8') as f:
  cross_indis_b_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_indis_c.txt', 'r', encoding='UTF-8') as f:
  cross_indis_c_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_indis_d.txt', 'r', encoding='UTF-8') as f:
  cross_indis_d_id = f.readlines()

with open('C:\ex\sen\data\max_square\cross\cross_indis_e.txt', 'r', encoding='UTF-8') as f:
  cross_indis_e_id = f.readlines()

# %%
print(cross_indis_e_id)
# Out:
# ["029'\n", "032'\n", "034'\n", "082'\n", "036'\n"]

# %%
# idのリストをファイルのリストにする
# 以下padding_600min
cross_egg_a_file = []
for sen_id in cross_egg_a_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_egg_a_file.append(file)
cross_egg_b_file = []
for sen_id in cross_egg_b_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_egg_b_file.append(file)
cross_egg_c_file = []
for sen_id in cross_egg_c_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_egg_c_file.append(file)
cross_egg_d_file = []
for sen_id in cross_egg_d_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_egg_d_file.append(file)
cross_egg_e_file = []
for sen_id in cross_egg_e_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_egg_e_file.append(file)
cross_indis_a_file = []
for sen_id in cross_indis_a_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_indis_a_file.append(file)
cross_indis_b_file = []
for sen_id in cross_indis_b_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_indis_b_file.append(file)
cross_indis_c_file = []
for sen_id in cross_indis_c_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_indis_c_file.append(file)
cross_indis_d_file = []
for sen_id in cross_indis_d_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_indis_d_file.append(file)
cross_indis_e_file = []
for sen_id in cross_indis_e_id:
  for file in glob.glob(os.path.join(project, sen_id[:-2] + '*')):
    cross_indis_e_file.append(file)

# %%
cross1train_egg=cross_egg_a_file + cross_egg_b_file +cross_egg_c_file+cross_egg_d_file
cross1val_egg=cross_egg_e_file
cross2train_egg=cross_egg_a_file + cross_egg_b_file +cross_egg_c_file+cross_egg_e_file
cross2val_egg=cross_egg_d_file
cross3train_egg=cross_egg_a_file + cross_egg_b_file +cross_egg_d_file+cross_egg_e_file
cross3val_egg=cross_egg_c_file

cross4train_egg=cross_egg_a_file +cross_egg_c_file+cross_egg_d_file+cross_egg_e_file
cross4val_egg=cross_egg_b_file

cross5train_egg= cross_egg_b_file +cross_egg_c_file+cross_egg_d_file+cross_egg_e_file
cross5val_egg=cross_egg_a_file

cross1train_indis= cross_indis_a_file + cross_indis_b_file + cross_indis_c_file + cross_indis_d_file
cross1val_indis = cross_indis_e_file

cross2train_indis= cross_indis_a_file + cross_indis_b_file + cross_indis_c_file +cross_indis_e_file
cross2val_indis =  cross_indis_d_file 

cross3train_indis= cross_indis_a_file + cross_indis_b_file + cross_indis_d_file + cross_indis_e_file
cross3val_indis =  cross_indis_c_file

cross4train_indis= cross_indis_a_file + cross_indis_c_file + cross_indis_d_file + cross_indis_e_file
cross4val_indis = cross_indis_b_file

cross5train_indis= cross_indis_b_file + cross_indis_c_file + cross_indis_d_file + cross_indis_e_file
cross5val_indis = cross_indis_a_file

# %%
def makedir(dir):
  if not os.path.exists(dir):
    os.makedirs(dir)

# %%
import shutil

out_path = os.path.join(project,"cross\cross1\\train\egg")
makedir(out_path)
for file in cross1train_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project,"cross\cross2\\train\egg")
makedir(out_path)
for file in cross2train_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project,"cross\cross3\\train\egg")
makedir(out_path)
for file in cross3train_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project,"cross\cross4\\train\egg")
makedir(out_path)
for file in cross4train_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project,"cross\cross5\\train\egg")
makedir(out_path)
for file in cross5train_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross1\\val\egg")
makedir(out_path)
for file in cross1val_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross2\\val\egg")
makedir(out_path)
for file in cross2val_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross3\\val\egg")
makedir(out_path)
for file in cross3val_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross4\\val\egg")
makedir(out_path)
for file in cross4val_egg:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross5\\val\egg")
makedir(out_path)
for file in cross5val_egg:
  shutil.copy(file,out_path)


out_path = os.path.join(project, "cross\cross1\\train\indis")
makedir(out_path)
for file in cross1train_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross2\\train\indis")
makedir(out_path)
for file in cross2train_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross3\\train\indis")
makedir(out_path)
for file in cross3train_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross4\\train\indis")
makedir(out_path)
for file in cross4train_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross5\\train\indis")
makedir(out_path)
for file in cross5train_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross1\\val\indis")
makedir(out_path)
for file in cross1val_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross2\\val\indis")
makedir(out_path)
for file in cross2val_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross3\\val\indis")
makedir(out_path)
for file in cross3val_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross4\\val\indis")
makedir(out_path)
for file in cross4val_indis:
  shutil.copy(file,out_path)

out_path = os.path.join(project, "cross\cross5\\val\indis")
makedir(out_path)
for file in cross5val_indis:
  shutil.copy(file,out_path)
