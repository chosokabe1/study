# %%
import matplotlib.pyplot as plt

file = "train_acc.txt"
file = "C:\ex\sen\max_square_efficientnetb7_out\\val_acc_hist.txt"
with open(file) as fileobj:
  text = fileobj.read()
  print(text)
  list = text.split(",")
  print(list)

data = []
for index,i in enumerate(list):
  print(index)
  i = i.replace("'", "")
  data.append(float(i))

plt.plot(data)
plt.title("train_accuracy-epoch")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.grid(True)
plt.show()
# Out:
# 0.5196078431372549,0.5196078431372549,0.5784313725490196,0.5392156862745098,0.6176470588235294,0.6764705882352942,0.6666666666666666,0.7941176470588235,0.7647058823529411,0.6470588235294118,0.7352941176470588,0.7058823529411764,0.7352941176470588,0.6372549019607843,0.803921568627451,0.8235294117647058,0.7745098039215687,0.6372549019607843,0.7745098039215687,0.8529411764705882,0.6764705882352942,0.7549019607843137,0.8235294117647058,0.7941176470588235,0.8235294117647058,0.8725490196078431,0.8137254901960784,0.8823529411764706,0.8137254901960784,0.9019607843137255,0.8823529411764706,0.892156862745098,0.8529411764705882,0.8627450980392157,0.8333333333333334,0.8333333333333334,0.8627450980392157,0.8627450980392157,0.8235294117647058,0.8627450980392157,0.8725490196078431,0.8725490196078431,0.8627450980392157,0.8333333333333334,0.7549019607843137,0.8431372549019608,0.8431372549019608,0.8529411764705882,0.8627450980392157,0.8725490196078431,0.8235294117647058,0.9019607843137255,0.9019607843
# ...
