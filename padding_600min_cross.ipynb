# %%
import glob
import os
a_egg = glob.glob('C:\ex\sen\data\padding_600min\cross\\a\\a\egg\*')
a_indis = glob.glob('C:\ex\sen\data\padding_600min\cross\\a\\a\indis\*')
b_egg = glob.glob('C:\ex\sen\data\padding_600min\cross\\b\\b\egg\*')
b_indis = glob.glob('C:\ex\sen\data\padding_600min\cross\\b\\b\indis\*')
c_egg = glob.glob('C:\ex\sen\data\padding_600min\cross\c\c\egg\*')
c_indis = glob.glob('C:\ex\sen\data\padding_600min\cross\c\c\indis\*')
d_egg = glob.glob('C:\ex\sen\data\padding_600min\cross\d\d\egg\*')
d_indis = glob.glob('C:\ex\sen\data\padding_600min\cross\d\d\indis\*')
e_egg = glob.glob('C:\ex\sen\data\padding_600min\cross\e\e\egg\*')
e_indis = glob.glob('C:\ex\sen\data\padding_600min\cross\e\e\indis\*')

# %%
cross1train_egg = b_egg + c_egg + d_egg
cross1val_egg = e_egg

cross2train_egg = c_egg + d_egg + e_egg
cross2val_egg = a_egg

cross3train_egg = d_egg + e_egg + a_egg
cross3val_egg = b_egg

cross4train_egg = e_egg + a_egg + b_egg
cross4val_egg = c_egg

cross5train_egg = a_egg + b_egg + c_egg
cross5val_egg = d_egg

cross1train_indis = b_indis + c_indis + d_indis
cross1val_indis = e_indis

cross2train_indis = c_indis + d_indis + e_indis
cross2val_indis = a_indis

cross3train_indis = d_indis + e_indis + a_indis
cross3val_indis = b_indis

cross4train_indis = e_indis + a_indis + b_indis
cross4val_indis = c_indis

cross5train_indis = a_indis + b_indis + c_indis
cross5val_indis = d_indis

# %%
def makedir(dir):
  if not os.path.exists(dir):
    os.makedirs(dir)

# %%
import shutil

out_path = "C:\ex\sen\data\padding_600min\cross\cross1\\train\egg"
makedir(out_path)
for file in cross1train_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross2\\train\egg"
makedir(out_path)
for file in cross2train_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross3\\train\egg"
makedir(out_path)
for file in cross3train_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross4\\train\egg"
makedir(out_path)
for file in cross4train_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross5\\train\egg"
makedir(out_path)
for file in cross5train_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross1\\val\egg"
makedir(out_path)
for file in cross1val_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross2\\val\egg"
makedir(out_path)
for file in cross2val_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross3\\val\egg"
makedir(out_path)
for file in cross3val_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross4\\val\egg"
makedir(out_path)
for file in cross4val_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross5\\val\egg"
makedir(out_path)
for file in cross5val_egg:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross1\\train\indis"
makedir(out_path)
for file in cross1train_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross2\\train\indis"
makedir(out_path)
for file in cross2train_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross3\\train\indis"
makedir(out_path)
for file in cross3train_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross4\\train\indis"
makedir(out_path)
for file in cross4train_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross5\\train\indis"
makedir(out_path)
for file in cross5train_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross1\\val\indis"
makedir(out_path)
for file in cross1val_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross2\\val\indis"
makedir(out_path)
for file in cross2val_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross3\\val\indis"
makedir(out_path)
for file in cross3val_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross4\\val\indis"
makedir(out_path)
for file in cross4val_indis:
  shutil.copy(file,out_path)

out_path = "C:\ex\sen\data\padding_600min\cross\cross5\\val\indis"
makedir(out_path)
for file in cross5val_indis:
  shutil.copy(file,out_path)
