# %% [markdown]
# 画像から正方形をスライディングウィンドウでトリミング

# %%
class Trim:
  # クラス変数
  # スライドが端に到達するか否かをXYそれぞれ判定する
  x_slide_finish = 0
  y_slide_finish = 0

  def __init__(self, size, gap, height, width):
    self.x_start = 0
    self.x_end = size
    self.y_start = 0
    self.y_end = size
    self.size = size
    self.x_max = width
    self.y_max = height
    self.gap = gap

  def x_slide(self):
    # x_slideがx_maxを超えるなら超えないように処理する。
    if self.x_end + self.gap > self.x_max:
      Trim.x_slide_finish = True
      self.x_end = self.x_max
      self.x_start = self.x_end - self.size
    else:  
      self.x_start += self.gap
      self.x_end += self.gap

  def y_slide(self):
    if self.y_end + self.gap > self.y_max:
      Trim.y_slide_finish = True
      self.y_end = self.y_max
      self.y_start = self.y_end - self.size
    else:
      self.y_start += self.gap
      self.y_end += self.gap

  # x が端に到達した後、yをスライドし、xを左に初期化する。
  def only_x_init(self):
    self.x_start = 0
    self.x_end = self.size

  # 現在の座標を表示する。
  def print_trim(self):
    print(f"({self.x_start}:{self.x_end})({self.y_start}:{self.y_end})")

# %%
import os
import cv2

def trim_square(square_size, slide_gap, img_path, out_path):
  img = cv2.imread(img_path)
  file_name = os.path.splitext(os.path.basename(img_path))[0]
  print(file_name)
  image_height, image_width = img.shape[:2]
  trim = Trim(square_size, slide_gap, image_height, image_width)

  Trim.y_slide_finish = False
  y_count = 0
  img_count = 0
  while(Trim.y_slide_finish == False):
    x_count = 0
    print(f"x:{x_count}回目, y:{y_count}回目")
    trim.print_trim()
    tmp = img[trim.y_start:trim.y_end, trim.x_start:trim.x_end]
    cv2.imwrite(out_path + '/' + file_name + '_' + f'{img_count}.jpg', tmp)
    img_count += 1
    Trim.x_slide_finish = False
    if image_width == square_size:
      Trim.x_slide_finish = True
    while(Trim.x_slide_finish == False):
      trim.x_slide()
      x_count += 1
      print(f"x:{x_count}回目, y:{y_count}回目")
      trim.print_trim()
      tmp = img[trim.y_start:trim.y_end, trim.x_start:trim.x_end]
      cv2.imwrite(out_path + '/' + file_name + '_' + f'{img_count}.jpg', tmp)
      img_count += 1
      print()
    
    trim.only_x_init()
    trim.y_slide()
    y_count += 1

  # 上記の二重ループではyの最後の段が無視されているので以下にyの最後の段
  print(f"x:{x_count}回目, y:{y_count}回目")
  tmp = img[trim.y_start:trim.y_end, trim.x_start:trim.x_end]
  cv2.imwrite(out_path + '/' + file_name + '_' + f'{img_count}.jpg', tmp)
  img_count += 1

  trim.print_trim()
  x_count = 0
  Trim.x_slide_finish = False
  if image_width == square_size:
    Trim.x_slide_finish = True
  while(Trim.x_slide_finish == False):
    trim.x_slide()
    x_count += 1
    print(f"x:{x_count}回目, y:{y_count}回目")
    trim.print_trim()
    tmp = img[trim.y_start:trim.y_end, trim.x_start:trim.x_end]
    cv2.imwrite(out_path + '/' + file_name + '_' + f'{img_count}.jpg', tmp)
    img_count += 1
    print()

# %%
import glob
import cv2
def makedir(dir):
  if not os.path.exists(dir):
    os.makedirs(dir)
out_path = "C:\ex\sen\data\padding_600min\cross\\c\\test\\trim_from_indis"
makedir(out_path)
square_size = 600
slide_gap = 300

for img_path in glob.glob("C:\ex\sen\data\padding_600min\cross\\c\\test\indis\*"):
  trim_square(square_size, slide_gap, img_path, out_path)
# Out:
# 007_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:0回目, y:3回目
# (0:600)(608:1208)
# 007_001
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(375:975)
# 007_002
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(416:1016)
# 007_003
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(375:975)
# 007_004
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (35:635)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (35:635)(300:900)
#
# x:1回目, y:2回目
# (0:600)(347:947)
# x:1回目, y:2回目
# (35:635)(347:947)
#
# 007_005
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (51:651)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (51:651)(300:900)
#
# x:1回目, y:2回目
# (0:600)(356:956)
# x:1回目, y:2回目
# (51:651)(356:956)
#
# 007_006
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (23:623)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (23:623)(300:900)
#
# x:1回目, y:2回目
# (0:600)(359:959)
# x:1回目, y:2回目
# (23:623)(359:959)
#
# 007_007
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(426:1026)
# 007_008
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(459:1059)
# 007_009
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(535:1135)
# 007_010
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(517:1117)
# 007_011
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(471:1071)
# 007_012
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(573:1173)
# 007_013
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:0回目, y:3回目
# (0:600)(620:1220)
# 007_014
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:0回目, y:3回目
# (0:600)(652:1252)
# 008_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:0回目, y:3回目
# (0:600)(751:1351)
# 009_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (87:687)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (87:687)(300:900)
#
# x:1回目, y:2回目
# (0:600)(402:1002)
# x:1回目, y:2回目
# (87:687)(402:1002)
#
# 009_001
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (83:683)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (83:683)(300:900)
#
# x:1回目, y:2回目
# (0:600)(365:965)
# x:1回目, y:2回目
# (83:683)(365:965)
#
# 009_002
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (63:663)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (63:663)(300:900)
#
# x:1回目, y:2回目
# (0:600)(321:921)
# x:1回目, y:2回目
# (63:663)(321:921)
#
# 009_003
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (71:671)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (71:671)(300:900)
#
# x:1回目, y:2回目
# (0:600)(397:997)
# x:1回目, y:2回目
# (71:671)(397:997)
#
# 009_004
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (73:673)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (73:673)(300:900)
#
# x:1回目, y:2回目
# (0:600)(346:946)
# x:1回目, y:2回目
# (73:673)(346:946)
#
# 009_005
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (89:689)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (89:689)(300:900)
#
# x:1回目, y:2回目
# (0:600)(304:904)
# x:1回目, y:2回目
# (89:689)(304:904)
#
# 009_006
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (64:664)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (64:664)(300:900)
#
# x:1回目, y:2回目
# (0:600)(348:948)
# x:1回目, y:2回目
# (64:664)(348:948)
#
# 009_007
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (69:669)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (69:669)(300:900)
#
# x:1回目, y:2回目
# (0:600)(386:986)
# x:1回目, y:2回目
# (69:669)(386:986)
#
# 009_008
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (14:614)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (14:614)(300:900)
#
# x:1回目, y:2回目
# (0:600)(490:1090)
# x:1回目, y:2回目
# (14:614)(490:1090)
#
# 009_009
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(469:1069)
# 009_010
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(559:1159)
# 011_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (489:1089)(0:600)
#
# x:2回目, y:1回目
# (0:600)(0:600)
# x:1回目, y:1回目
# (300:900)(0:600)
#
# x:2回目, y:1回目
# (489:1089)(0:600)
#
# 041_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (133:733)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (133:733)(300:900)
#
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:1回目, y:2回目
# (133:733)(600:1200)
#
# x:1回目, y:3回目
# (0:600)(843:1443)
# x:1回目, y:3回目
# (133:733)(843:1443)
#
# 055_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (514:1114)(0:600)
#
# x:2回目, y:1回目
# (0:600)(115:715)
# x:1回目, y:1回目
# (300:900)(115:715)
#
# x:2回目, y:1回目
# (514:1114)(115:715)
#
# 055_001
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (542:1142)(0:600)
#
# x:2回目, y:1回目
# (0:600)(210:810)
# x:1回目, y:1回目
# (300:900)(210:810)
#
# x:2回目, y:1回目
# (542:1142)(210:810)
#
# 056_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (600:1200)(0:600)
#
# x:3回目, y:0回目
# (862:1462)(0:600)
#
# x:3回目, y:1回目
# (0:600)(0:600)
# x:1回目, y:1回目
# (300:900)(0:600)
#
# x:2回目, y:1回目
# (600:1200)(0:600)
#
# x:3回目, y:1回目
# (862:1462)(0:600)
#
# 057_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (590:1190)(0:600)
#
# x:2回目, y:1回目
# (0:600)(44:644)
# x:1回目, y:1回目
# (300:900)(44:644)
#
# x:2回目, y:1回目
# (590:1190)(44:644)
#
# 058_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (53:653)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (53:653)(300:900)
#
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:1回目, y:2回目
# (53:653)(600:1200)
#
# x:1回目, y:3回目
# (0:600)(720:1320)
# x:1回目, y:3回目
# (53:653)(720:1320)
#
# 058_001
# x:0回目, y:0回目
# (0:600)(0:600)
# x:0回目, y:1回目
# (0:600)(300:900)
# x:0回目, y:2回目
# (0:600)(600:1200)
# x:0回目, y:3回目
# (0:600)(900:1500)
# x:0回目, y:4回目
# (0:600)(902:1502)
# 066_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (57:657)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (57:657)(300:900)
#
# x:1回目, y:2回目
# (0:600)(540:1140)
# x:1回目, y:2回目
# (57:657)(540:1140)
#
# 066_001
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (110:710)(0:600)
#
# x:0回目, y:1回目
# (0:600)(300:900)
# x:1回目, y:1回目
# (110:710)(300:900)
#
# x:1回目, y:2回目
# (0:600)(515:1115)
# x:1回目, y:2回目
# (110:710)(515:1115)
#
# 075_000
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (600:1200)(0:600)
#
# x:3回目, y:0回目
# (900:1500)(0:600)
#
# x:4回目, y:0回目
# (950:1550)(0:600)
#
# x:4回目, y:1回目
# (0:600)(0:600)
# x:1回目, y:1回目
# (300:900)(0:600)
#
# x:2回目, y:1回目
# (600:1200)(0:600)
#
# x:3回目, y:1回目
# (900:1500)(0:600)
#
# x:4回目, y:1回目
# (950:1550)(0:600)
#
# 075_001
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (600:1200)(0:600)
#
# x:3回目, y:0回目
# (900:1500)(0:600)
#
# x:4回目, y:0回目
# (985:1585)(0:600)
#
# x:4回目, y:1回目
# (0:600)(0:600)
# x:1回目, y:1回目
# (300:900)(0:600)
#
# x:2回目, y:1回目
# (600:1200)(0:600)
#
# x:3回目, y:1回目
# (900:1500)(0:600)
#
# x:4回目, y:1回目
# (985:1585)(0:600)
#
# 075_002
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (600:1200)(0:600)
#
# x:3回目, y:0回目
# (900:1500)(0:600)
#
# x:4回目, y:0回目
# (999:1599)(0:600)
#
# x:4回目, y:1回目
# (0:600)(0:600)
# x:1回目, y:1回目
# (300:900)(0:600)
#
# x:2回目, y:1回目
# (600:1200)(0:600)
#
# x:3回目, y:1回目
# (900:1500)(0:600)
#
# x:4回目, y:1回目
# (999:1599)(0:600)
#
# 075_003
# x:0回目, y:0回目
# (0:600)(0:600)
# x:1回目, y:0回目
# (300:900)(0:600)
#
# x:2回目, y:0回目
# (600:1200)(0:600)
#
# x:3回目, y:0回目
# (882:1482)(0:600)
#
# x:3回目, y:1回目
# (0:600)(0:600)
# x:1回目, y:1回目
# (300:900)(0:600)
#
# x:2回目, y:1回目
# (600:1200)(0:600)
#
# x:3回目, y:1回目
# (882:1482)(0:600)
